# %% [markdown]
# <div align="center">
#
# ###### Lab 2
#
# # National Tsing Hua University
#
# #### Spring 2024
#
# #### 11220IEEM 513600
#
# #### Deep Learning and Industrial Applications
#
# ## Lab 2: Predicting Heart Disease with Deep Learning
#
# </div>

# %% [markdown]
# ### Introduction
#
# In the realm of healthcare, early detection and accurate prediction of diseases play a crucial role in patient care and management. Heart disease remains one of the leading causes of mortality worldwide, making the development of effective diagnostic tools essential. This lab leverages deep learning to predict the presence of heart disease in patients using a subset of 14 key attributes from the Cleveland Heart Disease Database. The objective is to explore and apply deep learning techniques to distinguish between the presence and absence of heart disease based on clinical parameters.
#
# Throughout this lab, you'll engage with the following key activities:
# - Use [Pandas](https://pandas.pydata.org) to process the CSV files.
# - Use [PyTorch](https://pytorch.org) to build an Artificial Neural Network (ANN) to fit the dataset.
# - Evaluate the performance of the trained model to understand its accuracy.
#
# ### Attribute Information
#
# 1. age: Age of the patient in years
# 2. sex: (Male/Female)
# 3. cp: Chest pain type (4 types: low, medium, high, and severe)
# 4. trestbps: Resting blood pressure
# 5. chol: Serum cholesterol in mg/dl
# 6. fbs: Fasting blood sugar > 120 mg/dl
# 7. restecg: Resting electrocardiographic results (values 0,1,2)
# 8. thalach: Maximum heart rate achieved
# 9. exang: Exercise induced angina
# 10. oldpeak: Oldpeak = ST depression induced by exercise relative to rest
# 11. slope: The slope of the peak exercise ST segment
# 12. ca: Number of major vessels (0-3) colored by fluoroscopy
# 13. thal: 3 = normal; 6 = fixed defect; 7 = reversible defect
# 14. target: target have disease or not (1=yes, 0=no)
#
# ### References
# - [UCI Heart Disease Data](https://www.kaggle.com/datasets/redwankarimsony/heart-disease-data) for the dataset we use in this lab.

# %% [markdown]
# ## A. Checking and Preprocessing

# %%
import pandas as pd

df = pd.read_csv('heart_dataset_train_all.csv')
df
# Out:
#      age     sex      cp  trestbps   chol  fbs  restecg  thalach  exang  \
# 0     41    Male  medium     105.0  198.0    0      1.0    168.0      0
# 1     65  Female     low     120.0  177.0    0      1.0    140.0      0
# 2     44  Female  medium     130.0  219.0    0      0.0    188.0      0
# 3     54  Female    high     125.0  273.0    0      0.0    152.0      0
# 4     51  Female  severe     125.0  213.0    0      0.0    125.0      1
# ..   ...     ...     ...       ...    ...  ...      ...      ...    ...
# 268   40  Female     low     110.0  167.0    0      0.0    114.0      1
# 269   60  Female     low     117.0  230.0    1      1.0    160.0      1
# 270   64  Female    high     140.0  335.0    0      1.0    158.0      0
# 271   43  Female     low     120.0  177.0    0      0.0    120.0      1
# 272   57  Female     low     150.0  276.0    0      0.0    112.0      1
#
#      oldpeak  slope  ca  thal  target
# 0        0.0    2.0   1   2.0     1.0
# 1        0.4    2.0   0   3.0     1.0
# 2        0.0    2.0   0   2.0     1.0
# 3        0.5    0.0   1   2.0     1.0
# 4        1.4    2.0   1   2.0     1.0
# ..       ...    ...  ..   ...     ...
# 268      2.0    1.0   0   3.0     0.0
# 269      1.4    2.0   2   3.0     0.0
# 270      0.0    2.0   0   2.0     0.0
# 271      2.5    1.0   0   3.0     0.0
# 272      0.6    1.0   1   1.0     0.0
#
# [273 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       273 non-null    int64
#  1   sex       272 non-null    object
#  2   cp        272 non-null    object
#  3   trestbps  272 non-null    float64
#  4   chol      271 non-null    float64
#  5   fbs       273 non-null    int64
#  6   restecg   272 non-null    float64
#  7   thalach   272 non-null    float64
#  8   exang     273 non-null    int64
#  9   oldpeak   273 non-null    float64
#  10  slope     271 non-null    float64
#  11  ca        273 non-null    int64
#  12  thal      272 non-null    float64
#  13  target    272 non-null    float64
# dtypes: float64(8), int64(4), object(2)
# memory usage: 30.0+ KB

# %%
# checking for null values
df.isnull().sum()
# Out:
# age         0
# sex         1
# cp          1
# trestbps    1
# chol        2
# fbs         0
# restecg     1
# thalach     1
# exang       0
# oldpeak     0
# slope       2
# ca          0
# thal        1
# target      1
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (270, 14)

# %%
# Mapping 'sex' descriptions to numbers
sex_description = {
    'Male': 0,
    'Female': 1,
}
df.loc[:, 'sex'] = df['sex'].map(sex_description)

# Mapping 'cp' (chest pain) descriptions to numbers
pain_description = {
    'low': 0,
    'medium': 1,
    'high': 2,
    'severe': 3
}
df.loc[:, 'cp'] = df['cp'].map(pain_description)

df
# Out:
# <ipython-input-76-39abb612ef0e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'sex'] = df['sex'].map(sex_description)
# <ipython-input-76-39abb612ef0e>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'sex'] = df['sex'].map(sex_description)
# <ipython-input-76-39abb612ef0e>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'cp'] = df['cp'].map(pain_description)
# <ipython-input-76-39abb612ef0e>:15: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'cp'] = df['cp'].map(pain_description)
#      age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     41    0   1     105.0  198.0    0      1.0    168.0      0      0.0
# 1     65    1   0     120.0  177.0    0      1.0    140.0      0      0.4
# 2     44    1   1     130.0  219.0    0      0.0    188.0      0      0.0
# 3     54    1   2     125.0  273.0    0      0.0    152.0      0      0.5
# 4     51    1   3     125.0  213.0    0      0.0    125.0      1      1.4
# ..   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 268   40    1   0     110.0  167.0    0      0.0    114.0      1      2.0
# 269   60    1   0     117.0  230.0    1      1.0    160.0      1      1.4
# 270   64    1   2     140.0  335.0    0      1.0    158.0      0      0.0
# 271   43    1   0     120.0  177.0    0      0.0    120.0      1      2.5
# 272   57    1   0     150.0  276.0    0      0.0    112.0      1      0.6
#
#      slope  ca  thal  target
# 0      2.0   1   2.0     1.0
# 1      2.0   0   3.0     1.0
# 2      2.0   0   2.0     1.0
# 3      0.0   1   2.0     1.0
# 4      2.0   1   2.0     1.0
# ..     ...  ..   ...     ...
# 268    1.0   0   3.0     0.0
# 269    2.0   2   3.0     0.0
# 270    2.0   0   2.0     0.0
# 271    1.0   0   3.0     0.0
# 272    1.0   1   1.0     0.0
#
# [270 rows x 14 columns]

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  270.000000  270.000000  270.000000  270.000000  270.000000  270.000000
# mean    54.385185    0.685185    0.962963  131.525926  245.607407    0.151852
# std      9.149713    0.465305    1.023206   17.904675   51.529411    0.359544
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.250000    0.000000    0.000000  120.000000  210.250000    0.000000
# 50%     56.000000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  270.000000  270.000000  270.000000  270.000000  270.000000  270.000000
# mean     0.522222  149.807407    0.333333    1.024074    1.400000    0.744444
# std      0.529314   23.217253    0.472280    1.188379    0.618188    1.037166
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  134.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  152.500000    0.000000    0.600000    1.000000    0.000000
# 75%      1.000000  167.750000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  270.000000  270.000000
# mean     2.300000    0.544444
# std      0.623874    0.498946
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.062222 -0.103697  0.261782  0.210520  0.109847
# sex      -0.062222  1.000000 -0.040197 -0.055463 -0.166885  0.042384
# cp       -0.103697 -0.040197  1.000000  0.035563 -0.063592  0.065869
# trestbps  0.261782 -0.055463  0.035563  1.000000  0.128444  0.170606
# chol      0.210520 -0.166885 -0.063592  0.128444  1.000000  0.003430
# fbs       0.109847  0.042384  0.065869  0.170606  0.003430  1.000000
# restecg  -0.124588 -0.069599  0.008389 -0.145195 -0.162687 -0.086165
# thalach  -0.412624 -0.058626  0.300307 -0.056631 -0.023753 -0.014297
# exang     0.111263  0.124054 -0.428233  0.067116  0.063902  0.029190
# oldpeak   0.200243  0.089726 -0.183616  0.184896  0.084355  0.007943
# slope    -0.165360 -0.038771  0.135174 -0.126553 -0.031929 -0.056866
# ca        0.254462  0.140795 -0.180598  0.093545  0.068647  0.164266
# thal      0.077368  0.198493 -0.139765  0.068690  0.121280 -0.004972
# target   -0.244798 -0.283776  0.425574 -0.173239 -0.096773 -0.068845
#
#            restecg   thalach     exang   oldpeak     slope        ca  \
# age      -0.124588 -0.412624  0.111263  0.200243 -0.165360  0.254462
# sex      -0.069599 -0.058626  0.124054  0.089726 -0.038771  0.140795
# cp        0.008389  0.300307 -0.428233 -0.183616  0.135174 -0.180598
# trestbps -0.145195 -0.056631  0.067116  0.184896 -0.126553  0.093545
# chol     -0.162687 -0.023753  0.063902  0.084355 -0.031929  0.068647
# fbs      -0.086165 -0.014297  0.029190  0.007943 -0.056866  0.164266
# restecg   1.000000  0.025457 -0.089225 -0.047837  0.074982 -0.053946
# thalach   0.025457  1.000000 -0.404349 -0.340564  0.370073 -0.205060
# exang    -0.089225 -0.404349  1.000000  0.294308 -0.280124  0.106250
# oldpeak  -0.047837 -0.340564  0.294308  1.000000 -0.585472  0.223375
# slope     0.074982  0.370073 -0.280124 -0.585472  1.000000 -0.083491
# ca       -0.053946 -0.205060  0.106250  0.223375 -0.083491  1.000000
# thal     -0.003377 -0.078637  0.189253  0.200315 -0.090606  0.136160
# target    0.101817  0.432687 -0.457502 -0.443504  0.363983 -0.391031
#
#               thal    target
# age       0.077368 -0.244798
# sex       0.198493 -0.283776
# cp       -0.139765  0.425574
# trestbps  0.068690 -0.173239
# chol      0.121280 -0.096773
# fbs      -0.004972 -0.068845
# restecg  -0.003377  0.101817
# thalach  -0.078637  0.432687
# exang     0.189253 -0.457502
# oldpeak   0.200315 -0.443504
# slope    -0.090606  0.363983
# ca        0.136160 -0.391031
# thal      1.000000 -0.311701
# target   -0.311701  1.000000

# %% [markdown]
# #### Converting the DataFrame to a NumPy Array

# %%
import numpy as np

np_data = df.values
np_data.shape
# Out:
# (270, 14)

# %%
split_point = int(np_data.shape[0]*0.7)

np.random.shuffle(np_data)

x_train = np_data[:split_point, :13]
y_train = np_data[:split_point, 13]
x_val = np_data[split_point:, :13]
y_val = np_data[split_point:, 13]

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset

# Convert to PyTorch tensors
x_train = torch.from_numpy(x_train).float()
y_train = torch.from_numpy(y_train).long()

x_val = torch.from_numpy(x_val).float()
y_val = torch.from_numpy(y_val).long()

batch_size = 32

# Create datasets
train_dataset = TensorDataset(x_train, y_train)
val_dataset = TensorDataset(x_val, y_val)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

print(f'Number of samples in train and validation are {len(train_loader.dataset)} and {len(val_loader.dataset)}.')
# Out:
# Number of samples in train and validation are 189 and 81.

# %% [markdown]
# ## B. Defining Neural Networks
#
# In PyTorch, we can use **class** to define our custom neural network architectures by subclassing the `nn.Module` class. This gives our neural network all the functionality it needs to work with PyTorch's other utilities and keeps our implementation organized.
#
# - Neural networks are defined by subclassing `nn.Module`.
# - The layers of the neural network are initialized in the `__init__` method.
# - The forward pass operations on input data are defined in the `forward` method.
#
# It's worth noting that while we only define the forward pass, PyTorch will automatically derive the backward pass for us, which is used during training to update the model's weights."

# %%
import torch.nn as nn

class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(13, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, 2)
        ).cuda()

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ## C. Training the Neural Network

# %%
# Check your GPU status.
# !nvidia-smi
# Out:
# Tue Mar 19 07:13:48 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P0              28W /  70W |    161MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR, StepLR
from tqdm.auto import tqdm

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

epochs = 300

model = Model()
# print(model)

best_val_loss = float('inf')
best_val_acc = -1

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
lr_scheduler = CosineAnnealingLR(optimizer, T_max=epochs, eta_min=0)

for epoch in tqdm(range(epochs)):
    # Training
    model.train()
    total_loss = 0.0
    train_correct = 0
    total_train_samples = 0

    for features, labels in train_loader:
        features = features.cuda()
        labels = labels.cuda()

        outputs = model(features)

        loss = criterion(outputs, labels)
        total_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_predicted = outputs.argmax(-1)
        train_correct += (train_predicted == labels).sum().item()
        total_train_samples += labels.size(0)

    # Learning rate update
    lr_scheduler.step()

    avg_train_loss = total_loss / len(train_loader)
    train_accuracy = 100. * train_correct / total_train_samples

    # Validation
    model.eval()
    total_val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for features, labels in val_loader:
            features = features.cuda()
            labels = labels.cuda()

            outputs = model(features)

            loss = criterion(outputs, labels)
            total_val_loss += loss.item()

            predicted = outputs.argmax(-1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    avg_val_loss = total_val_loss / len(val_loader)
    val_accuracy = 100. * correct / total

    # Checkpoint
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss

    if val_accuracy > best_val_acc:
        best_val_acc = val_accuracy
        torch.save(model.state_dict(), 'model_classification.pth')

    print(f'Epoch {epoch+1}/{epochs}, Train loss: {avg_train_loss:.4f}, Train acc: {train_accuracy:.4f}%, Val loss: {avg_val_loss:.4f}, Val acc: {val_accuracy:.4f}%, Best Val loss: {best_val_loss:.4f} Best Val acc: {best_val_acc:.2f}%')

    # Store performance
    train_losses.append(avg_train_loss)
    train_accuracies.append(train_accuracy)
    val_losses.append(avg_val_loss)
    val_accuracies.append(val_accuracy)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# Epoch 1/300, Train loss: 5.7824, Train acc: 58.7302%, Val loss: 7.0454, Val acc: 48.1481%, Best Val loss: 7.0454 Best Val acc: 48.15%
# Epoch 2/300, Train loss: 5.0462, Train acc: 47.0899%, Val loss: 2.3542, Val acc: 53.0864%, Best Val loss: 2.3542 Best Val acc: 53.09%
# Epoch 3/300, Train loss: 2.2557, Train acc: 56.0847%, Val loss: 1.6778, Val acc: 55.5556%, Best Val loss: 1.6778 Best Val acc: 55.56%
# Epoch 4/300, Train loss: 1.9051, Train acc: 59.7884%, Val loss: 1.4419, Val acc: 58.0247%, Best Val loss: 1.4419 Best Val acc: 58.02%
# Epoch 5/300, Train loss: 1.0712, Train acc: 60.3175%, Val loss: 1.3428, Val acc: 59.2593%, Best Val loss: 1.3428 Best Val acc: 59.26%
# Epoch 6/300, Train loss: 0.8308, Train acc: 68.7831%, Val loss: 0.6687, Val acc: 69.1358%, Best Val loss: 0.6687 Best Val acc: 69.14%
# Epoch 7/300, Train loss: 0.7726, Train acc: 60.3175%, Val loss: 0.5808, Val acc: 69.1358%, Best Val loss: 0.5808 Best Val acc: 69.14%
# Epoch 8/300, Train loss: 0.6049, Train acc: 70.8995%, Val loss: 0.5542, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 74.07%
# Epoch 9/300, Train loss: 0.6105, Train acc: 64.5503%, Val loss: 0.5701, Val acc: 69.1358%, Best Val loss: 0.5542 Best Val acc: 74.07%
# Epoch 10/300, Train loss: 0.5475, Train acc: 70.3704%, Val loss: 0.6219, Val acc: 67.9012%, Best Val loss: 0.5542 Best Val acc: 74.07%
# Epoch 11/300, Train loss: 0.6194, Train acc: 61.9048%, Val loss: 0.6162, Val acc: 71.6049%, Best Val loss: 0.5542 Best Val acc: 74.07%
# Epoch 12/300, Train loss: 0.5940, Train acc: 70.3704%, Val loss: 0.6710, Val acc: 67.9012%, Best Val loss: 0.5542 Best Val acc: 74.07%
# Epoch 13/300, Train loss: 0.5498, Train acc: 70.3704%, Val loss: 0.6721, Val acc: 69.1358%, Best Val loss: 0.5542 Best Val acc: 74.07%
# Epoch 14/300, Train loss: 0.5946, Train acc: 66.6667%, Val loss: 0.6785, Val acc: 71.6049%, Best Val loss: 0.5542 Best Val acc: 74.07%
# Epoch 15/300, Train loss: 0.5310, Train acc: 70.3704%, Val loss: 0.6510, Val acc: 70.3704%, Best Val loss: 0.5542 Best Val acc: 74.07%
# Epoch 16/300, Train loss: 0.5277, Train acc: 72.4868%, Val loss: 0.6658, Val acc: 70.3704%, Best Val loss: 0.5542 Best Val acc: 74.07%
# Epoch 17/300, Train loss: 0.6059, Train acc: 64.5503%, Val loss: 0.9819, Val acc: 59.2593%, Best Val loss: 0.5542 Best Val acc: 74.07%
# Epoch 18/300, Train loss: 0.6702, Train acc: 64.0212%, Val loss: 0.8185, Val acc: 64.1975%, Best Val loss: 0.5542 Best Val acc: 74.07%
# Epoch 19/300, Train loss: 0.5815, Train acc: 68.2540%, Val loss: 0.6683, Val acc: 71.6049%, Best Val loss: 0.5542 Best Val acc: 74.07%
# Epoch 20/300, Train loss: 0.5217, Train acc: 72.4868%, Val loss: 0.7135, Val acc: 70.3704%, Best Val loss: 0.5542 Best Val acc: 74.07%
# Epoch 21/300, Train loss: 0.5123, Train acc: 74.0741%, Val loss: 0.8077, Val acc: 62.9630%, Best Val loss: 0.5542 Best Val acc: 74.07%
# Epoch 22/300, Train loss: 0.6346, Train acc: 64.0212%, Val loss: 0.7533, Val acc: 66.6667%, Best Val loss: 0.5542 Best Val acc: 74.07%
# Epoch 23/300, Train loss: 0.5181, Train acc: 73.5450%, Val loss: 0.6956, Val acc: 71.6049%, Best Val loss: 0.5542 Best Val acc: 74.07%
# Epoch 24/300, Train loss: 0.5784, Train acc: 71.9577%, Val loss: 0.8102, Val acc: 65.4321%, Best Val loss: 0.5542 Best Val acc: 74.07%
# Epoch 25/300, Train loss: 0.6153, Train acc: 67.7249%, Val loss: 0.8009, Val acc: 65.4321%, Best Val loss: 0.5542 Best Val acc: 74.07%
# Epoch 26/300, Train loss: 0.6199, Train acc: 65.6085%, Val loss: 0.8192, Val acc: 65.4321%, Best Val loss: 0.5542 Best Val acc: 74.07%
# Epoch 27/300, Train loss: 0.5479, Train acc: 73.0159%, Val loss: 0.7511, Val acc: 72.8395%, Best Val loss: 0.5542 Best Val acc: 74.07%
# Epoch 28/300, Train loss: 0.4800, Train acc: 75.6614%, Val loss: 0.7622, Val acc: 71.6049%, Best Val loss: 0.5542 Best Val acc: 74.07%
# Epoch 29/300, Train loss: 0.4867, Train acc: 77.7778%, Val loss: 0.7149, Val acc: 77.7778%, Best Val loss: 0.5542 Best Val acc: 77.78%
# Epoch 30/300, Train loss: 0.4611, Train acc: 76.1905%, Val loss: 0.7702, Val acc: 64.1975%, Best Val loss: 0.5542 Best Val acc: 77.78%
# Epoch 31/300, Train loss: 0.4928, Train acc: 71.9577%, Val loss: 0.7223, Val acc: 71.6049%, Best Val loss: 0.5542 Best Val acc: 77.78%
# Epoch 32/300, Train loss: 0.4841, Train acc: 77.2487%, Val loss: 0.7665, Val acc: 70.3704%, Best Val loss: 0.5542 Best Val acc: 77.78%
# Epoch 33/300, Train loss: 0.4952, Train acc: 75.1323%, Val loss: 0.7680, Val acc: 72.8395%, Best Val loss: 0.5542 Best Val acc: 77.78%
# Epoch 34/300, Train loss: 0.5001, Train acc: 76.1905%, Val loss: 0.7985, Val acc: 67.9012%, Best Val loss: 0.5542 Best Val acc: 77.78%
# Epoch 35/300, Train loss: 0.5415, Train acc: 69.8413%, Val loss: 0.7680, Val acc: 71.6049%, Best Val loss: 0.5542 Best Val acc: 77.78%
# Epoch 36/300, Train loss: 0.5279, Train acc: 74.6032%, Val loss: 0.7307, Val acc: 71.6049%, Best Val loss: 0.5542 Best Val acc: 77.78%
# Epoch 37/300, Train loss: 0.5156, Train acc: 72.4868%, Val loss: 0.9053, Val acc: 65.4321%, Best Val loss: 0.5542 Best Val acc: 77.78%
# Epoch 38/300, Train loss: 0.4806, Train acc: 80.4233%, Val loss: 0.7693, Val acc: 72.8395%, Best Val loss: 0.5542 Best Val acc: 77.78%
# Epoch 39/300, Train loss: 0.4662, Train acc: 75.1323%, Val loss: 0.7436, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 77.78%
# Epoch 40/300, Train loss: 0.4682, Train acc: 76.1905%, Val loss: 0.7428, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 77.78%
# Epoch 41/300, Train loss: 0.4201, Train acc: 82.0106%, Val loss: 0.7918, Val acc: 71.6049%, Best Val loss: 0.5542 Best Val acc: 77.78%
# Epoch 42/300, Train loss: 0.4661, Train acc: 75.6614%, Val loss: 0.7548, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 80.25%
# Epoch 43/300, Train loss: 0.4268, Train acc: 81.4815%, Val loss: 0.8043, Val acc: 72.8395%, Best Val loss: 0.5542 Best Val acc: 80.25%
# Epoch 44/300, Train loss: 0.4569, Train acc: 78.3069%, Val loss: 0.7738, Val acc: 72.8395%, Best Val loss: 0.5542 Best Val acc: 80.25%
# Epoch 45/300, Train loss: 0.5596, Train acc: 68.2540%, Val loss: 0.8667, Val acc: 55.5556%, Best Val loss: 0.5542 Best Val acc: 80.25%
# Epoch 46/300, Train loss: 0.4939, Train acc: 72.4868%, Val loss: 0.9115, Val acc: 55.5556%, Best Val loss: 0.5542 Best Val acc: 80.25%
# Epoch 47/300, Train loss: 0.5971, Train acc: 68.7831%, Val loss: 0.9050, Val acc: 56.7901%, Best Val loss: 0.5542 Best Val acc: 80.25%
# Epoch 48/300, Train loss: 0.5443, Train acc: 71.9577%, Val loss: 0.7720, Val acc: 75.3086%, Best Val loss: 0.5542 Best Val acc: 80.25%
# Epoch 49/300, Train loss: 0.5329, Train acc: 71.4286%, Val loss: 0.7240, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 80.25%
# Epoch 50/300, Train loss: 0.7107, Train acc: 65.6085%, Val loss: 0.7350, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 80.25%
# Epoch 51/300, Train loss: 0.8202, Train acc: 65.6085%, Val loss: 0.9228, Val acc: 66.6667%, Best Val loss: 0.5542 Best Val acc: 80.25%
# Epoch 52/300, Train loss: 0.7530, Train acc: 69.3122%, Val loss: 1.2562, Val acc: 54.3210%, Best Val loss: 0.5542 Best Val acc: 80.25%
# Epoch 53/300, Train loss: 0.8808, Train acc: 66.1376%, Val loss: 1.0835, Val acc: 55.5556%, Best Val loss: 0.5542 Best Val acc: 80.25%
# Epoch 54/300, Train loss: 0.8652, Train acc: 58.2011%, Val loss: 0.7387, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 80.25%
# Epoch 55/300, Train loss: 0.6922, Train acc: 65.6085%, Val loss: 1.0629, Val acc: 62.9630%, Best Val loss: 0.5542 Best Val acc: 80.25%
# Epoch 56/300, Train loss: 0.4440, Train acc: 76.1905%, Val loss: 0.8252, Val acc: 72.8395%, Best Val loss: 0.5542 Best Val acc: 80.25%
# Epoch 57/300, Train loss: 0.5189, Train acc: 77.2487%, Val loss: 0.6898, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 80.25%
# Epoch 58/300, Train loss: 0.5170, Train acc: 77.2487%, Val loss: 0.7385, Val acc: 72.8395%, Best Val loss: 0.5542 Best Val acc: 80.25%
# Epoch 59/300, Train loss: 0.4274, Train acc: 79.8942%, Val loss: 0.6772, Val acc: 81.4815%, Best Val loss: 0.5542 Best Val acc: 81.48%
# Epoch 60/300, Train loss: 0.4157, Train acc: 80.4233%, Val loss: 0.7017, Val acc: 75.3086%, Best Val loss: 0.5542 Best Val acc: 81.48%
# Epoch 61/300, Train loss: 0.3978, Train acc: 82.0106%, Val loss: 0.6999, Val acc: 81.4815%, Best Val loss: 0.5542 Best Val acc: 81.48%
# Epoch 62/300, Train loss: 0.4196, Train acc: 78.3069%, Val loss: 0.7209, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 81.48%
# Epoch 63/300, Train loss: 0.4315, Train acc: 79.8942%, Val loss: 0.7971, Val acc: 64.1975%, Best Val loss: 0.5542 Best Val acc: 81.48%
# Epoch 64/300, Train loss: 0.4323, Train acc: 78.3069%, Val loss: 0.6834, Val acc: 82.7160%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 65/300, Train loss: 0.3891, Train acc: 81.4815%, Val loss: 0.7024, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 66/300, Train loss: 0.3656, Train acc: 84.1270%, Val loss: 0.6911, Val acc: 81.4815%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 67/300, Train loss: 0.3961, Train acc: 80.9524%, Val loss: 0.8073, Val acc: 60.4938%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 68/300, Train loss: 0.4420, Train acc: 75.1323%, Val loss: 0.6945, Val acc: 81.4815%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 69/300, Train loss: 0.3960, Train acc: 83.5979%, Val loss: 0.7150, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 70/300, Train loss: 0.4184, Train acc: 79.3651%, Val loss: 0.7035, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 71/300, Train loss: 0.3947, Train acc: 82.0106%, Val loss: 0.7086, Val acc: 81.4815%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 72/300, Train loss: 0.3935, Train acc: 82.0106%, Val loss: 0.7464, Val acc: 76.5432%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 73/300, Train loss: 0.4072, Train acc: 79.8942%, Val loss: 0.8007, Val acc: 69.1358%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 74/300, Train loss: 0.4176, Train acc: 82.0106%, Val loss: 0.7199, Val acc: 77.7778%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 75/300, Train loss: 0.3674, Train acc: 79.3651%, Val loss: 0.8740, Val acc: 70.3704%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 76/300, Train loss: 0.3804, Train acc: 80.9524%, Val loss: 0.7484, Val acc: 72.8395%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 77/300, Train loss: 0.3631, Train acc: 83.0688%, Val loss: 0.6922, Val acc: 81.4815%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 78/300, Train loss: 0.3584, Train acc: 85.1852%, Val loss: 0.7101, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 79/300, Train loss: 0.4740, Train acc: 76.1905%, Val loss: 0.7392, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 80/300, Train loss: 0.4965, Train acc: 74.6032%, Val loss: 0.8932, Val acc: 70.3704%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 81/300, Train loss: 0.5549, Train acc: 69.8413%, Val loss: 1.1369, Val acc: 65.4321%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 82/300, Train loss: 0.5553, Train acc: 73.0159%, Val loss: 1.3265, Val acc: 61.7284%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 83/300, Train loss: 0.7819, Train acc: 68.7831%, Val loss: 0.7253, Val acc: 77.7778%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 84/300, Train loss: 0.5715, Train acc: 73.0159%, Val loss: 0.9439, Val acc: 59.2593%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 85/300, Train loss: 0.5281, Train acc: 78.8360%, Val loss: 0.8530, Val acc: 72.8395%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 86/300, Train loss: 0.4946, Train acc: 75.6614%, Val loss: 1.0826, Val acc: 66.6667%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 87/300, Train loss: 0.5275, Train acc: 76.7196%, Val loss: 0.7549, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 88/300, Train loss: 0.5324, Train acc: 75.1323%, Val loss: 1.0208, Val acc: 56.7901%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 89/300, Train loss: 0.6561, Train acc: 70.8995%, Val loss: 0.6915, Val acc: 81.4815%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 90/300, Train loss: 0.5485, Train acc: 73.5450%, Val loss: 1.5648, Val acc: 59.2593%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 91/300, Train loss: 0.6000, Train acc: 77.7778%, Val loss: 0.9660, Val acc: 59.2593%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 92/300, Train loss: 0.5318, Train acc: 75.6614%, Val loss: 0.7208, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 93/300, Train loss: 0.4467, Train acc: 79.3651%, Val loss: 0.8953, Val acc: 71.6049%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 94/300, Train loss: 0.4207, Train acc: 76.7196%, Val loss: 0.7246, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 95/300, Train loss: 0.3947, Train acc: 80.9524%, Val loss: 0.7341, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 96/300, Train loss: 0.3482, Train acc: 82.5397%, Val loss: 0.9301, Val acc: 69.1358%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 97/300, Train loss: 0.4026, Train acc: 77.2487%, Val loss: 0.6776, Val acc: 81.4815%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 98/300, Train loss: 0.3751, Train acc: 83.5979%, Val loss: 0.6951, Val acc: 81.4815%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 99/300, Train loss: 0.3354, Train acc: 84.6561%, Val loss: 0.9019, Val acc: 71.6049%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 100/300, Train loss: 0.3921, Train acc: 82.5397%, Val loss: 0.7263, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 101/300, Train loss: 0.3651, Train acc: 83.0688%, Val loss: 0.7081, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 82.72%
# Epoch 102/300, Train loss: 0.4300, Train acc: 78.8360%, Val loss: 0.6852, Val acc: 83.9506%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 103/300, Train loss: 0.3796, Train acc: 83.5979%, Val loss: 0.8941, Val acc: 70.3704%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 104/300, Train loss: 0.3777, Train acc: 82.5397%, Val loss: 0.7570, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 105/300, Train loss: 0.3532, Train acc: 84.1270%, Val loss: 0.7061, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 106/300, Train loss: 0.3209, Train acc: 86.2434%, Val loss: 0.7406, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 107/300, Train loss: 0.3252, Train acc: 86.7725%, Val loss: 0.7163, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 108/300, Train loss: 0.3265, Train acc: 87.8307%, Val loss: 0.7353, Val acc: 77.7778%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 109/300, Train loss: 0.3389, Train acc: 82.5397%, Val loss: 0.7962, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 110/300, Train loss: 0.3292, Train acc: 86.7725%, Val loss: 0.7236, Val acc: 82.7160%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 111/300, Train loss: 0.3263, Train acc: 84.1270%, Val loss: 0.7244, Val acc: 81.4815%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 112/300, Train loss: 0.3274, Train acc: 85.7143%, Val loss: 0.7911, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 113/300, Train loss: 0.3479, Train acc: 82.5397%, Val loss: 0.7555, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 114/300, Train loss: 0.3405, Train acc: 84.1270%, Val loss: 0.7165, Val acc: 77.7778%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 115/300, Train loss: 0.3405, Train acc: 83.5979%, Val loss: 0.7511, Val acc: 76.5432%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 116/300, Train loss: 0.3156, Train acc: 86.2434%, Val loss: 0.7827, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 117/300, Train loss: 0.3251, Train acc: 85.1852%, Val loss: 0.7474, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 118/300, Train loss: 0.3435, Train acc: 85.1852%, Val loss: 0.7674, Val acc: 75.3086%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 119/300, Train loss: 0.3494, Train acc: 84.1270%, Val loss: 0.9374, Val acc: 71.6049%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 120/300, Train loss: 0.3331, Train acc: 85.1852%, Val loss: 0.7458, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 121/300, Train loss: 0.3191, Train acc: 85.7143%, Val loss: 0.7288, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 122/300, Train loss: 0.3134, Train acc: 85.7143%, Val loss: 0.8092, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 123/300, Train loss: 0.3106, Train acc: 87.3016%, Val loss: 0.7493, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 124/300, Train loss: 0.3465, Train acc: 86.7725%, Val loss: 0.8642, Val acc: 75.3086%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 125/300, Train loss: 0.3676, Train acc: 83.0688%, Val loss: 0.8980, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 126/300, Train loss: 0.3398, Train acc: 83.5979%, Val loss: 0.7529, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 127/300, Train loss: 0.3066, Train acc: 86.2434%, Val loss: 0.7397, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 128/300, Train loss: 0.3013, Train acc: 86.2434%, Val loss: 0.8786, Val acc: 75.3086%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 129/300, Train loss: 0.3139, Train acc: 84.6561%, Val loss: 0.7560, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 130/300, Train loss: 0.3181, Train acc: 83.5979%, Val loss: 0.9129, Val acc: 72.8395%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 131/300, Train loss: 0.3394, Train acc: 84.6561%, Val loss: 0.8372, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 132/300, Train loss: 0.3410, Train acc: 85.1852%, Val loss: 0.7655, Val acc: 77.7778%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 133/300, Train loss: 0.3205, Train acc: 83.5979%, Val loss: 1.0162, Val acc: 70.3704%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 134/300, Train loss: 0.4358, Train acc: 80.4233%, Val loss: 0.8173, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 135/300, Train loss: 0.4226, Train acc: 79.8942%, Val loss: 0.8536, Val acc: 69.1358%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 136/300, Train loss: 0.4619, Train acc: 77.7778%, Val loss: 0.9082, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 137/300, Train loss: 0.3251, Train acc: 87.3016%, Val loss: 0.7849, Val acc: 76.5432%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 138/300, Train loss: 0.3501, Train acc: 82.5397%, Val loss: 0.7317, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 139/300, Train loss: 0.3185, Train acc: 86.7725%, Val loss: 0.7481, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 140/300, Train loss: 0.2953, Train acc: 87.8307%, Val loss: 0.7648, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 141/300, Train loss: 0.3018, Train acc: 87.8307%, Val loss: 0.7852, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 142/300, Train loss: 0.3091, Train acc: 85.1852%, Val loss: 0.7617, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 143/300, Train loss: 0.3035, Train acc: 85.1852%, Val loss: 0.7697, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 144/300, Train loss: 0.2922, Train acc: 87.3016%, Val loss: 0.7941, Val acc: 77.7778%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 145/300, Train loss: 0.2944, Train acc: 89.4180%, Val loss: 0.8120, Val acc: 76.5432%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 146/300, Train loss: 0.3107, Train acc: 86.2434%, Val loss: 0.8329, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 147/300, Train loss: 0.3212, Train acc: 84.6561%, Val loss: 0.8832, Val acc: 75.3086%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 148/300, Train loss: 0.3274, Train acc: 84.6561%, Val loss: 0.7576, Val acc: 81.4815%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 149/300, Train loss: 0.3053, Train acc: 85.7143%, Val loss: 0.7803, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 150/300, Train loss: 0.3013, Train acc: 86.7725%, Val loss: 0.8921, Val acc: 75.3086%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 151/300, Train loss: 0.3271, Train acc: 84.6561%, Val loss: 0.7676, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 152/300, Train loss: 0.2980, Train acc: 83.5979%, Val loss: 0.7761, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 153/300, Train loss: 0.2924, Train acc: 87.8307%, Val loss: 0.8450, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 154/300, Train loss: 0.2884, Train acc: 87.8307%, Val loss: 0.7761, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 155/300, Train loss: 0.3033, Train acc: 85.7143%, Val loss: 0.7807, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 156/300, Train loss: 0.2978, Train acc: 86.7725%, Val loss: 0.8462, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 157/300, Train loss: 0.3025, Train acc: 86.2434%, Val loss: 0.8587, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 158/300, Train loss: 0.2933, Train acc: 86.2434%, Val loss: 0.7840, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 159/300, Train loss: 0.2808, Train acc: 86.2434%, Val loss: 0.8335, Val acc: 76.5432%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 160/300, Train loss: 0.3082, Train acc: 84.1270%, Val loss: 0.7840, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 161/300, Train loss: 0.2748, Train acc: 88.3598%, Val loss: 0.8422, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 162/300, Train loss: 0.2928, Train acc: 87.3016%, Val loss: 0.7948, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 163/300, Train loss: 0.2783, Train acc: 87.3016%, Val loss: 0.8068, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 164/300, Train loss: 0.2896, Train acc: 88.8889%, Val loss: 0.7879, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 165/300, Train loss: 0.2729, Train acc: 88.8889%, Val loss: 0.8786, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 166/300, Train loss: 0.2811, Train acc: 86.2434%, Val loss: 0.7944, Val acc: 76.5432%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 167/300, Train loss: 0.3228, Train acc: 85.1852%, Val loss: 0.9349, Val acc: 75.3086%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 168/300, Train loss: 0.3515, Train acc: 84.1270%, Val loss: 0.8764, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 169/300, Train loss: 0.2983, Train acc: 85.1852%, Val loss: 0.7926, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 170/300, Train loss: 0.2892, Train acc: 86.7725%, Val loss: 0.9485, Val acc: 75.3086%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 171/300, Train loss: 0.3233, Train acc: 83.5979%, Val loss: 0.7960, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 172/300, Train loss: 0.3093, Train acc: 83.0688%, Val loss: 0.7897, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 173/300, Train loss: 0.2981, Train acc: 84.6561%, Val loss: 0.8434, Val acc: 76.5432%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 174/300, Train loss: 0.2667, Train acc: 87.8307%, Val loss: 0.7999, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 175/300, Train loss: 0.2740, Train acc: 86.7725%, Val loss: 0.8853, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 176/300, Train loss: 0.2891, Train acc: 87.3016%, Val loss: 0.8169, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 177/300, Train loss: 0.2689, Train acc: 88.8889%, Val loss: 0.8552, Val acc: 76.5432%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 178/300, Train loss: 0.2890, Train acc: 86.2434%, Val loss: 0.8275, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 179/300, Train loss: 0.2781, Train acc: 87.3016%, Val loss: 0.8215, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 180/300, Train loss: 0.2698, Train acc: 88.8889%, Val loss: 0.8174, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 181/300, Train loss: 0.2932, Train acc: 85.7143%, Val loss: 0.8639, Val acc: 76.5432%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 182/300, Train loss: 0.2919, Train acc: 88.3598%, Val loss: 0.8733, Val acc: 75.3086%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 183/300, Train loss: 0.2914, Train acc: 85.7143%, Val loss: 0.8117, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 184/300, Train loss: 0.2923, Train acc: 87.8307%, Val loss: 1.0284, Val acc: 75.3086%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 185/300, Train loss: 0.3302, Train acc: 84.1270%, Val loss: 0.8136, Val acc: 76.5432%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 186/300, Train loss: 0.2963, Train acc: 88.8889%, Val loss: 0.9739, Val acc: 75.3086%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 187/300, Train loss: 0.2913, Train acc: 88.8889%, Val loss: 0.8140, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 188/300, Train loss: 0.3188, Train acc: 83.5979%, Val loss: 0.8270, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 189/300, Train loss: 0.3329, Train acc: 86.2434%, Val loss: 0.9941, Val acc: 75.3086%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 190/300, Train loss: 0.3781, Train acc: 82.5397%, Val loss: 0.8116, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 191/300, Train loss: 0.3037, Train acc: 87.8307%, Val loss: 0.9292, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 192/300, Train loss: 0.3037, Train acc: 85.7143%, Val loss: 0.8083, Val acc: 81.4815%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 193/300, Train loss: 0.2832, Train acc: 86.2434%, Val loss: 0.9192, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 194/300, Train loss: 0.2636, Train acc: 86.2434%, Val loss: 0.8111, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 195/300, Train loss: 0.3090, Train acc: 86.7725%, Val loss: 0.9113, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 196/300, Train loss: 0.3242, Train acc: 85.1852%, Val loss: 0.8401, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 197/300, Train loss: 0.3373, Train acc: 85.1852%, Val loss: 0.8944, Val acc: 75.3086%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 198/300, Train loss: 0.3117, Train acc: 86.7725%, Val loss: 0.8201, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 199/300, Train loss: 0.3178, Train acc: 84.1270%, Val loss: 0.8303, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 200/300, Train loss: 0.3264, Train acc: 83.5979%, Val loss: 0.8989, Val acc: 74.0741%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 201/300, Train loss: 0.2953, Train acc: 84.6561%, Val loss: 0.8526, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 202/300, Train loss: 0.2732, Train acc: 89.4180%, Val loss: 0.8335, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 203/300, Train loss: 0.2800, Train acc: 87.3016%, Val loss: 0.8646, Val acc: 77.7778%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 204/300, Train loss: 0.2628, Train acc: 87.3016%, Val loss: 0.8222, Val acc: 81.4815%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 205/300, Train loss: 0.2649, Train acc: 88.3598%, Val loss: 0.8818, Val acc: 75.3086%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 206/300, Train loss: 0.2760, Train acc: 87.3016%, Val loss: 0.8224, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 207/300, Train loss: 0.2703, Train acc: 88.3598%, Val loss: 0.8751, Val acc: 77.7778%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 208/300, Train loss: 0.2644, Train acc: 88.8889%, Val loss: 0.8606, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 209/300, Train loss: 0.2656, Train acc: 88.3598%, Val loss: 0.8638, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 210/300, Train loss: 0.2676, Train acc: 88.8889%, Val loss: 0.8565, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 211/300, Train loss: 0.2596, Train acc: 88.8889%, Val loss: 0.8954, Val acc: 75.3086%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 212/300, Train loss: 0.2624, Train acc: 89.4180%, Val loss: 0.8485, Val acc: 81.4815%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 213/300, Train loss: 0.2668, Train acc: 87.8307%, Val loss: 0.9166, Val acc: 75.3086%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 214/300, Train loss: 0.2742, Train acc: 85.7143%, Val loss: 0.8490, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 215/300, Train loss: 0.2711, Train acc: 87.8307%, Val loss: 0.8615, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 216/300, Train loss: 0.2589, Train acc: 89.9471%, Val loss: 0.8713, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 217/300, Train loss: 0.2600, Train acc: 88.3598%, Val loss: 0.8741, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 218/300, Train loss: 0.2641, Train acc: 89.4180%, Val loss: 0.8776, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 219/300, Train loss: 0.2631, Train acc: 89.4180%, Val loss: 0.8667, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 220/300, Train loss: 0.2570, Train acc: 89.9471%, Val loss: 0.8759, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 221/300, Train loss: 0.2681, Train acc: 88.3598%, Val loss: 0.8491, Val acc: 80.2469%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 222/300, Train loss: 0.2623, Train acc: 87.8307%, Val loss: 0.8851, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 223/300, Train loss: 0.2576, Train acc: 90.4762%, Val loss: 0.8803, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 224/300, Train loss: 0.2582, Train acc: 89.9471%, Val loss: 0.8743, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 225/300, Train loss: 0.2589, Train acc: 88.8889%, Val loss: 0.8604, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 226/300, Train loss: 0.2542, Train acc: 91.0053%, Val loss: 0.8915, Val acc: 77.7778%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 227/300, Train loss: 0.2551, Train acc: 89.4180%, Val loss: 0.8660, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 228/300, Train loss: 0.2582, Train acc: 88.8889%, Val loss: 0.8616, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 229/300, Train loss: 0.2569, Train acc: 89.4180%, Val loss: 0.8689, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 230/300, Train loss: 0.2578, Train acc: 88.8889%, Val loss: 0.8800, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 231/300, Train loss: 0.2560, Train acc: 90.4762%, Val loss: 0.8792, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 232/300, Train loss: 0.2574, Train acc: 88.8889%, Val loss: 0.8635, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 233/300, Train loss: 0.2539, Train acc: 89.9471%, Val loss: 0.9024, Val acc: 77.7778%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 234/300, Train loss: 0.2571, Train acc: 89.4180%, Val loss: 0.8653, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 235/300, Train loss: 0.2543, Train acc: 89.9471%, Val loss: 0.8897, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 236/300, Train loss: 0.2538, Train acc: 90.4762%, Val loss: 0.8811, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 237/300, Train loss: 0.2573, Train acc: 89.4180%, Val loss: 0.8741, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 238/300, Train loss: 0.2649, Train acc: 88.8889%, Val loss: 0.9150, Val acc: 76.5432%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 239/300, Train loss: 0.2620, Train acc: 87.8307%, Val loss: 0.8566, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 240/300, Train loss: 0.2617, Train acc: 87.8307%, Val loss: 0.9079, Val acc: 76.5432%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 241/300, Train loss: 0.2531, Train acc: 90.4762%, Val loss: 0.8731, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 242/300, Train loss: 0.2559, Train acc: 89.4180%, Val loss: 0.8895, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 243/300, Train loss: 0.2513, Train acc: 89.4180%, Val loss: 0.8797, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 244/300, Train loss: 0.2591, Train acc: 89.4180%, Val loss: 0.8669, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 245/300, Train loss: 0.2561, Train acc: 88.8889%, Val loss: 0.9077, Val acc: 77.7778%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 246/300, Train loss: 0.2524, Train acc: 89.4180%, Val loss: 0.8898, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 247/300, Train loss: 0.2543, Train acc: 91.0053%, Val loss: 0.8684, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 248/300, Train loss: 0.2615, Train acc: 88.3598%, Val loss: 0.9066, Val acc: 77.7778%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 249/300, Train loss: 0.2519, Train acc: 89.9471%, Val loss: 0.8754, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 250/300, Train loss: 0.2521, Train acc: 89.9471%, Val loss: 0.8758, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 251/300, Train loss: 0.2539, Train acc: 90.4762%, Val loss: 0.8999, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 252/300, Train loss: 0.2525, Train acc: 90.4762%, Val loss: 0.8901, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 253/300, Train loss: 0.2522, Train acc: 89.4180%, Val loss: 0.8766, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 254/300, Train loss: 0.2523, Train acc: 89.4180%, Val loss: 0.8952, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 255/300, Train loss: 0.2530, Train acc: 88.8889%, Val loss: 0.8979, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 256/300, Train loss: 0.2481, Train acc: 90.4762%, Val loss: 0.8779, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 257/300, Train loss: 0.2534, Train acc: 89.4180%, Val loss: 0.8797, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 258/300, Train loss: 0.2519, Train acc: 89.9471%, Val loss: 0.9077, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 259/300, Train loss: 0.2516, Train acc: 89.9471%, Val loss: 0.8899, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 260/300, Train loss: 0.2521, Train acc: 90.4762%, Val loss: 0.8787, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 261/300, Train loss: 0.2632, Train acc: 87.8307%, Val loss: 0.9137, Val acc: 77.7778%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 262/300, Train loss: 0.2501, Train acc: 89.4180%, Val loss: 0.8892, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 263/300, Train loss: 0.2502, Train acc: 89.9471%, Val loss: 0.8820, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 264/300, Train loss: 0.2488, Train acc: 90.4762%, Val loss: 0.8874, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 265/300, Train loss: 0.2536, Train acc: 89.4180%, Val loss: 0.9017, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 266/300, Train loss: 0.2515, Train acc: 89.9471%, Val loss: 0.8834, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 267/300, Train loss: 0.2500, Train acc: 91.0053%, Val loss: 0.8930, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 268/300, Train loss: 0.2479, Train acc: 90.4762%, Val loss: 0.8982, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 269/300, Train loss: 0.2498, Train acc: 91.0053%, Val loss: 0.8912, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 270/300, Train loss: 0.2498, Train acc: 90.4762%, Val loss: 0.8892, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 271/300, Train loss: 0.2498, Train acc: 90.4762%, Val loss: 0.8913, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 272/300, Train loss: 0.2472, Train acc: 90.4762%, Val loss: 0.8972, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 273/300, Train loss: 0.2477, Train acc: 90.4762%, Val loss: 0.8949, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 274/300, Train loss: 0.2504, Train acc: 90.4762%, Val loss: 0.8896, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 275/300, Train loss: 0.2480, Train acc: 89.9471%, Val loss: 0.8895, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 276/300, Train loss: 0.2482, Train acc: 90.4762%, Val loss: 0.8933, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 277/300, Train loss: 0.2480, Train acc: 91.0053%, Val loss: 0.8992, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 278/300, Train loss: 0.2473, Train acc: 91.0053%, Val loss: 0.9004, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 279/300, Train loss: 0.2496, Train acc: 90.4762%, Val loss: 0.8932, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 280/300, Train loss: 0.2475, Train acc: 90.4762%, Val loss: 0.8948, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 281/300, Train loss: 0.2484, Train acc: 90.4762%, Val loss: 0.8958, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 282/300, Train loss: 0.2501, Train acc: 90.4762%, Val loss: 0.8929, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 283/300, Train loss: 0.2484, Train acc: 90.4762%, Val loss: 0.8933, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 284/300, Train loss: 0.2488, Train acc: 90.4762%, Val loss: 0.8935, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 285/300, Train loss: 0.2512, Train acc: 90.4762%, Val loss: 0.8981, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 286/300, Train loss: 0.2478, Train acc: 90.4762%, Val loss: 0.8975, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 287/300, Train loss: 0.2492, Train acc: 90.4762%, Val loss: 0.8959, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 288/300, Train loss: 0.2475, Train acc: 90.4762%, Val loss: 0.8945, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 289/300, Train loss: 0.2492, Train acc: 90.4762%, Val loss: 0.8949, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 290/300, Train loss: 0.2486, Train acc: 90.4762%, Val loss: 0.8954, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 291/300, Train loss: 0.2488, Train acc: 90.4762%, Val loss: 0.8952, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 292/300, Train loss: 0.2474, Train acc: 90.4762%, Val loss: 0.8947, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 293/300, Train loss: 0.2506, Train acc: 90.4762%, Val loss: 0.8944, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 294/300, Train loss: 0.2464, Train acc: 90.4762%, Val loss: 0.8942, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 295/300, Train loss: 0.2483, Train acc: 90.4762%, Val loss: 0.8941, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 296/300, Train loss: 0.2471, Train acc: 90.4762%, Val loss: 0.8943, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 297/300, Train loss: 0.2458, Train acc: 90.4762%, Val loss: 0.8942, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 298/300, Train loss: 0.2476, Train acc: 90.4762%, Val loss: 0.8943, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 299/300, Train loss: 0.2473, Train acc: 90.4762%, Val loss: 0.8943, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%
# Epoch 300/300, Train loss: 0.2492, Train acc: 90.4762%, Val loss: 0.8943, Val acc: 79.0123%, Best Val loss: 0.5542 Best Val acc: 83.95%

# %% [markdown]
# #### Visualizing the model performance

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

# Plotting training and validation accuracy
ax[0].plot(train_accuracies)
ax[0].plot(val_accuracies)
ax[0].set_title('Model Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(['Train', 'Val'])

# Plotting training and validation loss
ax[1].plot(train_losses)
ax[1].plot(val_losses)
ax[1].set_title('Model Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(['Train', 'Val'])

plt.show()

# %% [markdown]
# ## D. Evaluating Your Trained Model

# %%
# read test file
test_data = pd.read_csv('heart_dataset_test.csv')
test_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   50    0   2       120   219    0        1      158      0      1.6      1
# 1   58    0   2       120   340    0        1      172      0      0.0      2
# 2   66    0   3       150   226    0        1      114      0      2.6      0
# 3   43    1   0       150   247    0        1      171      0      1.5      2
# 4   69    0   3       140   239    0        1      151      0      1.8      2
#
#    ca  thal  target
# 0   0     2       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   2     2       1

# %%
test_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
test_data = test_data.values
test_data.shape
# Out:
# (31, 14)

# %%
# Convert to PyTorch tensors
x_test = torch.from_numpy(test_data[:, :13]).float()
y_test = torch.from_numpy(test_data[:, 13]).long()

# Create datasets
test_dataset = TensorDataset(x_test, y_test)

# Create dataloaders
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
# Load the trained weights
model.load_state_dict(torch.load('model_classification.pth'))

# Set the model to evaluation mode
model.eval()

test_correct = 0
test_total = 0

with torch.no_grad():
    for features, labels in test_loader:

        features = features.cuda()
        labels = labels.cuda()

        outputs = model(features)

        predicted = outputs.argmax(-1)
        test_correct += (predicted == labels).sum().item()
        test_total += labels.size(0)

print(f'Test accuracy is {100. * test_correct / test_total}%')
# Out:
# Test accuracy is 74.19354838709677%
