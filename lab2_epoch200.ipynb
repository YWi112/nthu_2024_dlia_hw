# %% [markdown]
# <div align="center">
#
# ###### Lab 2
#
# # National Tsing Hua University
#
# #### Spring 2024
#
# #### 11220IEEM 513600
#
# #### Deep Learning and Industrial Applications
#
# ## Lab 2: Predicting Heart Disease with Deep Learning
#
# </div>

# %% [markdown]
# ### Introduction
#
# In the realm of healthcare, early detection and accurate prediction of diseases play a crucial role in patient care and management. Heart disease remains one of the leading causes of mortality worldwide, making the development of effective diagnostic tools essential. This lab leverages deep learning to predict the presence of heart disease in patients using a subset of 14 key attributes from the Cleveland Heart Disease Database. The objective is to explore and apply deep learning techniques to distinguish between the presence and absence of heart disease based on clinical parameters.
#
# Throughout this lab, you'll engage with the following key activities:
# - Use [Pandas](https://pandas.pydata.org) to process the CSV files.
# - Use [PyTorch](https://pytorch.org) to build an Artificial Neural Network (ANN) to fit the dataset.
# - Evaluate the performance of the trained model to understand its accuracy.
#
# ### Attribute Information
#
# 1. age: Age of the patient in years
# 2. sex: (Male/Female)
# 3. cp: Chest pain type (4 types: low, medium, high, and severe)
# 4. trestbps: Resting blood pressure
# 5. chol: Serum cholesterol in mg/dl
# 6. fbs: Fasting blood sugar > 120 mg/dl
# 7. restecg: Resting electrocardiographic results (values 0,1,2)
# 8. thalach: Maximum heart rate achieved
# 9. exang: Exercise induced angina
# 10. oldpeak: Oldpeak = ST depression induced by exercise relative to rest
# 11. slope: The slope of the peak exercise ST segment
# 12. ca: Number of major vessels (0-3) colored by fluoroscopy
# 13. thal: 3 = normal; 6 = fixed defect; 7 = reversible defect
# 14. target: target have disease or not (1=yes, 0=no)
#
# ### References
# - [UCI Heart Disease Data](https://www.kaggle.com/datasets/redwankarimsony/heart-disease-data) for the dataset we use in this lab.

# %% [markdown]
# ## A. Checking and Preprocessing

# %%
import pandas as pd

df = pd.read_csv('heart_dataset_train_all.csv')
df
# Out:
#      age     sex      cp  trestbps   chol  fbs  restecg  thalach  exang  \
# 0     41    Male  medium     105.0  198.0    0      1.0    168.0      0
# 1     65  Female     low     120.0  177.0    0      1.0    140.0      0
# 2     44  Female  medium     130.0  219.0    0      0.0    188.0      0
# 3     54  Female    high     125.0  273.0    0      0.0    152.0      0
# 4     51  Female  severe     125.0  213.0    0      0.0    125.0      1
# ..   ...     ...     ...       ...    ...  ...      ...      ...    ...
# 268   40  Female     low     110.0  167.0    0      0.0    114.0      1
# 269   60  Female     low     117.0  230.0    1      1.0    160.0      1
# 270   64  Female    high     140.0  335.0    0      1.0    158.0      0
# 271   43  Female     low     120.0  177.0    0      0.0    120.0      1
# 272   57  Female     low     150.0  276.0    0      0.0    112.0      1
#
#      oldpeak  slope  ca  thal  target
# 0        0.0    2.0   1   2.0     1.0
# 1        0.4    2.0   0   3.0     1.0
# 2        0.0    2.0   0   2.0     1.0
# 3        0.5    0.0   1   2.0     1.0
# 4        1.4    2.0   1   2.0     1.0
# ..       ...    ...  ..   ...     ...
# 268      2.0    1.0   0   3.0     0.0
# 269      1.4    2.0   2   3.0     0.0
# 270      0.0    2.0   0   2.0     0.0
# 271      2.5    1.0   0   3.0     0.0
# 272      0.6    1.0   1   1.0     0.0
#
# [273 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       273 non-null    int64
#  1   sex       272 non-null    object
#  2   cp        272 non-null    object
#  3   trestbps  272 non-null    float64
#  4   chol      271 non-null    float64
#  5   fbs       273 non-null    int64
#  6   restecg   272 non-null    float64
#  7   thalach   272 non-null    float64
#  8   exang     273 non-null    int64
#  9   oldpeak   273 non-null    float64
#  10  slope     271 non-null    float64
#  11  ca        273 non-null    int64
#  12  thal      272 non-null    float64
#  13  target    272 non-null    float64
# dtypes: float64(8), int64(4), object(2)
# memory usage: 30.0+ KB

# %%
# checking for null values
df.isnull().sum()
# Out:
# age         0
# sex         1
# cp          1
# trestbps    1
# chol        2
# fbs         0
# restecg     1
# thalach     1
# exang       0
# oldpeak     0
# slope       2
# ca          0
# thal        1
# target      1
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (270, 14)

# %%
# Mapping 'sex' descriptions to numbers
sex_description = {
    'Male': 0,
    'Female': 1,
}
df.loc[:, 'sex'] = df['sex'].map(sex_description)

# Mapping 'cp' (chest pain) descriptions to numbers
pain_description = {
    'low': 0,
    'medium': 1,
    'high': 2,
    'severe': 3
}
df.loc[:, 'cp'] = df['cp'].map(pain_description)

df
# Out:
# <ipython-input-55-39abb612ef0e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'sex'] = df['sex'].map(sex_description)
# <ipython-input-55-39abb612ef0e>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'sex'] = df['sex'].map(sex_description)
# <ipython-input-55-39abb612ef0e>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'cp'] = df['cp'].map(pain_description)
# <ipython-input-55-39abb612ef0e>:15: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'cp'] = df['cp'].map(pain_description)
#      age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     41    0   1     105.0  198.0    0      1.0    168.0      0      0.0
# 1     65    1   0     120.0  177.0    0      1.0    140.0      0      0.4
# 2     44    1   1     130.0  219.0    0      0.0    188.0      0      0.0
# 3     54    1   2     125.0  273.0    0      0.0    152.0      0      0.5
# 4     51    1   3     125.0  213.0    0      0.0    125.0      1      1.4
# ..   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 268   40    1   0     110.0  167.0    0      0.0    114.0      1      2.0
# 269   60    1   0     117.0  230.0    1      1.0    160.0      1      1.4
# 270   64    1   2     140.0  335.0    0      1.0    158.0      0      0.0
# 271   43    1   0     120.0  177.0    0      0.0    120.0      1      2.5
# 272   57    1   0     150.0  276.0    0      0.0    112.0      1      0.6
#
#      slope  ca  thal  target
# 0      2.0   1   2.0     1.0
# 1      2.0   0   3.0     1.0
# 2      2.0   0   2.0     1.0
# 3      0.0   1   2.0     1.0
# 4      2.0   1   2.0     1.0
# ..     ...  ..   ...     ...
# 268    1.0   0   3.0     0.0
# 269    2.0   2   3.0     0.0
# 270    2.0   0   2.0     0.0
# 271    1.0   0   3.0     0.0
# 272    1.0   1   1.0     0.0
#
# [270 rows x 14 columns]

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  270.000000  270.000000  270.000000  270.000000  270.000000  270.000000
# mean    54.385185    0.685185    0.962963  131.525926  245.607407    0.151852
# std      9.149713    0.465305    1.023206   17.904675   51.529411    0.359544
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.250000    0.000000    0.000000  120.000000  210.250000    0.000000
# 50%     56.000000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  270.000000  270.000000  270.000000  270.000000  270.000000  270.000000
# mean     0.522222  149.807407    0.333333    1.024074    1.400000    0.744444
# std      0.529314   23.217253    0.472280    1.188379    0.618188    1.037166
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  134.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  152.500000    0.000000    0.600000    1.000000    0.000000
# 75%      1.000000  167.750000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  270.000000  270.000000
# mean     2.300000    0.544444
# std      0.623874    0.498946
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.062222 -0.103697  0.261782  0.210520  0.109847
# sex      -0.062222  1.000000 -0.040197 -0.055463 -0.166885  0.042384
# cp       -0.103697 -0.040197  1.000000  0.035563 -0.063592  0.065869
# trestbps  0.261782 -0.055463  0.035563  1.000000  0.128444  0.170606
# chol      0.210520 -0.166885 -0.063592  0.128444  1.000000  0.003430
# fbs       0.109847  0.042384  0.065869  0.170606  0.003430  1.000000
# restecg  -0.124588 -0.069599  0.008389 -0.145195 -0.162687 -0.086165
# thalach  -0.412624 -0.058626  0.300307 -0.056631 -0.023753 -0.014297
# exang     0.111263  0.124054 -0.428233  0.067116  0.063902  0.029190
# oldpeak   0.200243  0.089726 -0.183616  0.184896  0.084355  0.007943
# slope    -0.165360 -0.038771  0.135174 -0.126553 -0.031929 -0.056866
# ca        0.254462  0.140795 -0.180598  0.093545  0.068647  0.164266
# thal      0.077368  0.198493 -0.139765  0.068690  0.121280 -0.004972
# target   -0.244798 -0.283776  0.425574 -0.173239 -0.096773 -0.068845
#
#            restecg   thalach     exang   oldpeak     slope        ca  \
# age      -0.124588 -0.412624  0.111263  0.200243 -0.165360  0.254462
# sex      -0.069599 -0.058626  0.124054  0.089726 -0.038771  0.140795
# cp        0.008389  0.300307 -0.428233 -0.183616  0.135174 -0.180598
# trestbps -0.145195 -0.056631  0.067116  0.184896 -0.126553  0.093545
# chol     -0.162687 -0.023753  0.063902  0.084355 -0.031929  0.068647
# fbs      -0.086165 -0.014297  0.029190  0.007943 -0.056866  0.164266
# restecg   1.000000  0.025457 -0.089225 -0.047837  0.074982 -0.053946
# thalach   0.025457  1.000000 -0.404349 -0.340564  0.370073 -0.205060
# exang    -0.089225 -0.404349  1.000000  0.294308 -0.280124  0.106250
# oldpeak  -0.047837 -0.340564  0.294308  1.000000 -0.585472  0.223375
# slope     0.074982  0.370073 -0.280124 -0.585472  1.000000 -0.083491
# ca       -0.053946 -0.205060  0.106250  0.223375 -0.083491  1.000000
# thal     -0.003377 -0.078637  0.189253  0.200315 -0.090606  0.136160
# target    0.101817  0.432687 -0.457502 -0.443504  0.363983 -0.391031
#
#               thal    target
# age       0.077368 -0.244798
# sex       0.198493 -0.283776
# cp       -0.139765  0.425574
# trestbps  0.068690 -0.173239
# chol      0.121280 -0.096773
# fbs      -0.004972 -0.068845
# restecg  -0.003377  0.101817
# thalach  -0.078637  0.432687
# exang     0.189253 -0.457502
# oldpeak   0.200315 -0.443504
# slope    -0.090606  0.363983
# ca        0.136160 -0.391031
# thal      1.000000 -0.311701
# target   -0.311701  1.000000

# %% [markdown]
# #### Converting the DataFrame to a NumPy Array

# %%
import numpy as np

np_data = df.values
np_data.shape
# Out:
# (270, 14)

# %%
split_point = int(np_data.shape[0]*0.7)

np.random.shuffle(np_data)

x_train = np_data[:split_point, :13]
y_train = np_data[:split_point, 13]
x_val = np_data[split_point:, :13]
y_val = np_data[split_point:, 13]

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset

# Convert to PyTorch tensors
x_train = torch.from_numpy(x_train).float()
y_train = torch.from_numpy(y_train).long()

x_val = torch.from_numpy(x_val).float()
y_val = torch.from_numpy(y_val).long()

batch_size = 32

# Create datasets
train_dataset = TensorDataset(x_train, y_train)
val_dataset = TensorDataset(x_val, y_val)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

print(f'Number of samples in train and validation are {len(train_loader.dataset)} and {len(val_loader.dataset)}.')
# Out:
# Number of samples in train and validation are 189 and 81.

# %% [markdown]
# ## B. Defining Neural Networks
#
# In PyTorch, we can use **class** to define our custom neural network architectures by subclassing the `nn.Module` class. This gives our neural network all the functionality it needs to work with PyTorch's other utilities and keeps our implementation organized.
#
# - Neural networks are defined by subclassing `nn.Module`.
# - The layers of the neural network are initialized in the `__init__` method.
# - The forward pass operations on input data are defined in the `forward` method.
#
# It's worth noting that while we only define the forward pass, PyTorch will automatically derive the backward pass for us, which is used during training to update the model's weights."

# %%
import torch.nn as nn

class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(13, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, 2)
        ).cuda()

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ## C. Training the Neural Network

# %%
# Check your GPU status.
# !nvidia-smi
# Out:
# Tue Mar 19 07:09:20 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P0              28W /  70W |    161MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR, StepLR
from tqdm.auto import tqdm

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

epochs = 200

model = Model()
# print(model)

best_val_loss = float('inf')
best_val_acc = -1

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
lr_scheduler = CosineAnnealingLR(optimizer, T_max=epochs, eta_min=0)

for epoch in tqdm(range(epochs)):
    # Training
    model.train()
    total_loss = 0.0
    train_correct = 0
    total_train_samples = 0

    for features, labels in train_loader:
        features = features.cuda()
        labels = labels.cuda()

        outputs = model(features)

        loss = criterion(outputs, labels)
        total_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_predicted = outputs.argmax(-1)
        train_correct += (train_predicted == labels).sum().item()
        total_train_samples += labels.size(0)

    # Learning rate update
    lr_scheduler.step()

    avg_train_loss = total_loss / len(train_loader)
    train_accuracy = 100. * train_correct / total_train_samples

    # Validation
    model.eval()
    total_val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for features, labels in val_loader:
            features = features.cuda()
            labels = labels.cuda()

            outputs = model(features)

            loss = criterion(outputs, labels)
            total_val_loss += loss.item()

            predicted = outputs.argmax(-1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    avg_val_loss = total_val_loss / len(val_loader)
    val_accuracy = 100. * correct / total

    # Checkpoint
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss

    if val_accuracy > best_val_acc:
        best_val_acc = val_accuracy
        torch.save(model.state_dict(), 'model_classification.pth')

    print(f'Epoch {epoch+1}/{epochs}, Train loss: {avg_train_loss:.4f}, Train acc: {train_accuracy:.4f}%, Val loss: {avg_val_loss:.4f}, Val acc: {val_accuracy:.4f}%, Best Val loss: {best_val_loss:.4f} Best Val acc: {best_val_acc:.2f}%')

    # Store performance
    train_losses.append(avg_train_loss)
    train_accuracies.append(train_accuracy)
    val_losses.append(avg_val_loss)
    val_accuracies.append(val_accuracy)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch 1/200, Train loss: 5.7765, Train acc: 48.6772%, Val loss: 1.6599, Val acc: 51.8519%, Best Val loss: 1.6599 Best Val acc: 51.85%
# Epoch 2/200, Train loss: 1.1946, Train acc: 56.6138%, Val loss: 0.6982, Val acc: 70.3704%, Best Val loss: 0.6982 Best Val acc: 70.37%
# Epoch 3/200, Train loss: 0.8842, Train acc: 57.6720%, Val loss: 0.5758, Val acc: 71.6049%, Best Val loss: 0.5758 Best Val acc: 71.60%
# Epoch 4/200, Train loss: 0.6171, Train acc: 68.2540%, Val loss: 0.7154, Val acc: 61.7284%, Best Val loss: 0.5758 Best Val acc: 71.60%
# Epoch 5/200, Train loss: 0.6231, Train acc: 68.7831%, Val loss: 0.7574, Val acc: 59.2593%, Best Val loss: 0.5758 Best Val acc: 71.60%
# Epoch 6/200, Train loss: 0.8022, Train acc: 62.4339%, Val loss: 0.6047, Val acc: 69.1358%, Best Val loss: 0.5758 Best Val acc: 71.60%
# Epoch 7/200, Train loss: 0.6785, Train acc: 62.9630%, Val loss: 0.5147, Val acc: 76.5432%, Best Val loss: 0.5147 Best Val acc: 76.54%
# Epoch 8/200, Train loss: 0.6030, Train acc: 70.8995%, Val loss: 0.5798, Val acc: 67.9012%, Best Val loss: 0.5147 Best Val acc: 76.54%
# Epoch 9/200, Train loss: 0.6623, Train acc: 64.5503%, Val loss: 0.4966, Val acc: 76.5432%, Best Val loss: 0.4966 Best Val acc: 76.54%
# Epoch 10/200, Train loss: 0.6443, Train acc: 65.6085%, Val loss: 0.6483, Val acc: 62.9630%, Best Val loss: 0.4966 Best Val acc: 76.54%
# Epoch 11/200, Train loss: 0.6820, Train acc: 62.9630%, Val loss: 0.5282, Val acc: 74.0741%, Best Val loss: 0.4966 Best Val acc: 76.54%
# Epoch 12/200, Train loss: 1.0192, Train acc: 59.2593%, Val loss: 0.6283, Val acc: 64.1975%, Best Val loss: 0.4966 Best Val acc: 76.54%
# Epoch 13/200, Train loss: 0.6826, Train acc: 66.6667%, Val loss: 0.4973, Val acc: 75.3086%, Best Val loss: 0.4966 Best Val acc: 76.54%
# Epoch 14/200, Train loss: 0.5782, Train acc: 71.9577%, Val loss: 0.5630, Val acc: 69.1358%, Best Val loss: 0.4966 Best Val acc: 76.54%
# Epoch 15/200, Train loss: 0.8290, Train acc: 57.6720%, Val loss: 0.6818, Val acc: 62.9630%, Best Val loss: 0.4966 Best Val acc: 76.54%
# Epoch 16/200, Train loss: 0.6471, Train acc: 70.8995%, Val loss: 0.9894, Val acc: 56.7901%, Best Val loss: 0.4966 Best Val acc: 76.54%
# Epoch 17/200, Train loss: 0.6768, Train acc: 65.0794%, Val loss: 0.6330, Val acc: 62.9630%, Best Val loss: 0.4966 Best Val acc: 76.54%
# Epoch 18/200, Train loss: 0.7202, Train acc: 64.5503%, Val loss: 0.6974, Val acc: 62.9630%, Best Val loss: 0.4966 Best Val acc: 76.54%
# Epoch 19/200, Train loss: 0.5266, Train acc: 75.6614%, Val loss: 0.5899, Val acc: 67.9012%, Best Val loss: 0.4966 Best Val acc: 76.54%
# Epoch 20/200, Train loss: 0.6121, Train acc: 66.1376%, Val loss: 0.7577, Val acc: 64.1975%, Best Val loss: 0.4966 Best Val acc: 76.54%
# Epoch 21/200, Train loss: 0.7194, Train acc: 64.0212%, Val loss: 0.4742, Val acc: 77.7778%, Best Val loss: 0.4742 Best Val acc: 77.78%
# Epoch 22/200, Train loss: 0.7327, Train acc: 66.1376%, Val loss: 0.5374, Val acc: 71.6049%, Best Val loss: 0.4742 Best Val acc: 77.78%
# Epoch 23/200, Train loss: 0.5717, Train acc: 69.8413%, Val loss: 0.5657, Val acc: 67.9012%, Best Val loss: 0.4742 Best Val acc: 77.78%
# Epoch 24/200, Train loss: 0.6764, Train acc: 66.1376%, Val loss: 0.7543, Val acc: 61.7284%, Best Val loss: 0.4742 Best Val acc: 77.78%
# Epoch 25/200, Train loss: 0.5680, Train acc: 72.4868%, Val loss: 0.5386, Val acc: 69.1358%, Best Val loss: 0.4742 Best Val acc: 77.78%
# Epoch 26/200, Train loss: 0.5451, Train acc: 74.0741%, Val loss: 0.4668, Val acc: 79.0123%, Best Val loss: 0.4668 Best Val acc: 79.01%
# Epoch 27/200, Train loss: 0.5357, Train acc: 72.4868%, Val loss: 0.5100, Val acc: 75.3086%, Best Val loss: 0.4668 Best Val acc: 79.01%
# Epoch 28/200, Train loss: 0.5730, Train acc: 67.1958%, Val loss: 0.4982, Val acc: 76.5432%, Best Val loss: 0.4668 Best Val acc: 79.01%
# Epoch 29/200, Train loss: 0.5222, Train acc: 71.4286%, Val loss: 0.5504, Val acc: 69.1358%, Best Val loss: 0.4668 Best Val acc: 79.01%
# Epoch 30/200, Train loss: 0.5236, Train acc: 71.9577%, Val loss: 0.5591, Val acc: 67.9012%, Best Val loss: 0.4668 Best Val acc: 79.01%
# Epoch 31/200, Train loss: 0.5614, Train acc: 69.8413%, Val loss: 0.5046, Val acc: 76.5432%, Best Val loss: 0.4668 Best Val acc: 79.01%
# Epoch 32/200, Train loss: 0.6764, Train acc: 66.6667%, Val loss: 0.5660, Val acc: 70.3704%, Best Val loss: 0.4668 Best Val acc: 79.01%
# Epoch 33/200, Train loss: 0.5616, Train acc: 69.3122%, Val loss: 0.5210, Val acc: 75.3086%, Best Val loss: 0.4668 Best Val acc: 79.01%
# Epoch 34/200, Train loss: 0.5176, Train acc: 73.5450%, Val loss: 0.4916, Val acc: 75.3086%, Best Val loss: 0.4668 Best Val acc: 79.01%
# Epoch 35/200, Train loss: 0.4827, Train acc: 74.6032%, Val loss: 0.4402, Val acc: 80.2469%, Best Val loss: 0.4402 Best Val acc: 80.25%
# Epoch 36/200, Train loss: 0.5167, Train acc: 73.0159%, Val loss: 0.5113, Val acc: 75.3086%, Best Val loss: 0.4402 Best Val acc: 80.25%
# Epoch 37/200, Train loss: 0.4992, Train acc: 77.2487%, Val loss: 0.4476, Val acc: 82.7160%, Best Val loss: 0.4402 Best Val acc: 82.72%
# Epoch 38/200, Train loss: 0.4942, Train acc: 77.2487%, Val loss: 0.5367, Val acc: 65.4321%, Best Val loss: 0.4402 Best Val acc: 82.72%
# Epoch 39/200, Train loss: 0.5074, Train acc: 74.6032%, Val loss: 0.5794, Val acc: 62.9630%, Best Val loss: 0.4402 Best Val acc: 82.72%
# Epoch 40/200, Train loss: 0.4930, Train acc: 75.1323%, Val loss: 0.4345, Val acc: 80.2469%, Best Val loss: 0.4345 Best Val acc: 82.72%
# Epoch 41/200, Train loss: 0.4790, Train acc: 77.2487%, Val loss: 0.5248, Val acc: 70.3704%, Best Val loss: 0.4345 Best Val acc: 82.72%
# Epoch 42/200, Train loss: 0.5182, Train acc: 73.5450%, Val loss: 0.6542, Val acc: 61.7284%, Best Val loss: 0.4345 Best Val acc: 82.72%
# Epoch 43/200, Train loss: 0.5469, Train acc: 70.8995%, Val loss: 0.5192, Val acc: 71.6049%, Best Val loss: 0.4345 Best Val acc: 82.72%
# Epoch 44/200, Train loss: 0.6059, Train acc: 66.6667%, Val loss: 0.5458, Val acc: 66.6667%, Best Val loss: 0.4345 Best Val acc: 82.72%
# Epoch 45/200, Train loss: 0.5770, Train acc: 71.4286%, Val loss: 0.5474, Val acc: 65.4321%, Best Val loss: 0.4345 Best Val acc: 82.72%
# Epoch 46/200, Train loss: 0.5094, Train acc: 75.6614%, Val loss: 0.4284, Val acc: 81.4815%, Best Val loss: 0.4284 Best Val acc: 82.72%
# Epoch 47/200, Train loss: 0.4510, Train acc: 81.4815%, Val loss: 0.4215, Val acc: 81.4815%, Best Val loss: 0.4215 Best Val acc: 82.72%
# Epoch 48/200, Train loss: 0.4919, Train acc: 74.0741%, Val loss: 0.4450, Val acc: 81.4815%, Best Val loss: 0.4215 Best Val acc: 82.72%
# Epoch 49/200, Train loss: 0.5237, Train acc: 69.8413%, Val loss: 0.4372, Val acc: 79.0123%, Best Val loss: 0.4215 Best Val acc: 82.72%
# Epoch 50/200, Train loss: 0.5104, Train acc: 75.1323%, Val loss: 0.4543, Val acc: 79.0123%, Best Val loss: 0.4215 Best Val acc: 82.72%
# Epoch 51/200, Train loss: 0.5221, Train acc: 73.0159%, Val loss: 0.4212, Val acc: 80.2469%, Best Val loss: 0.4212 Best Val acc: 82.72%
# Epoch 52/200, Train loss: 0.4881, Train acc: 75.1323%, Val loss: 0.4305, Val acc: 81.4815%, Best Val loss: 0.4212 Best Val acc: 82.72%
# Epoch 53/200, Train loss: 0.4632, Train acc: 75.1323%, Val loss: 0.4291, Val acc: 80.2469%, Best Val loss: 0.4212 Best Val acc: 82.72%
# Epoch 54/200, Train loss: 0.4565, Train acc: 78.3069%, Val loss: 0.4756, Val acc: 79.0123%, Best Val loss: 0.4212 Best Val acc: 82.72%
# Epoch 55/200, Train loss: 0.5069, Train acc: 71.9577%, Val loss: 0.6678, Val acc: 67.9012%, Best Val loss: 0.4212 Best Val acc: 82.72%
# Epoch 56/200, Train loss: 0.5656, Train acc: 69.3122%, Val loss: 0.5549, Val acc: 75.3086%, Best Val loss: 0.4212 Best Val acc: 82.72%
# Epoch 57/200, Train loss: 0.4646, Train acc: 78.8360%, Val loss: 0.4561, Val acc: 79.0123%, Best Val loss: 0.4212 Best Val acc: 82.72%
# Epoch 58/200, Train loss: 0.4423, Train acc: 75.6614%, Val loss: 0.4033, Val acc: 83.9506%, Best Val loss: 0.4033 Best Val acc: 83.95%
# Epoch 59/200, Train loss: 0.4072, Train acc: 81.4815%, Val loss: 0.4061, Val acc: 83.9506%, Best Val loss: 0.4033 Best Val acc: 83.95%
# Epoch 60/200, Train loss: 0.4196, Train acc: 79.3651%, Val loss: 0.4579, Val acc: 75.3086%, Best Val loss: 0.4033 Best Val acc: 83.95%
# Epoch 61/200, Train loss: 0.4278, Train acc: 78.8360%, Val loss: 0.4489, Val acc: 79.0123%, Best Val loss: 0.4033 Best Val acc: 83.95%
# Epoch 62/200, Train loss: 0.4303, Train acc: 79.3651%, Val loss: 0.4012, Val acc: 85.1852%, Best Val loss: 0.4012 Best Val acc: 85.19%
# Epoch 63/200, Train loss: 0.4671, Train acc: 75.1323%, Val loss: 0.4021, Val acc: 83.9506%, Best Val loss: 0.4012 Best Val acc: 85.19%
# Epoch 64/200, Train loss: 0.4247, Train acc: 80.4233%, Val loss: 0.4580, Val acc: 79.0123%, Best Val loss: 0.4012 Best Val acc: 85.19%
# Epoch 65/200, Train loss: 0.4604, Train acc: 78.8360%, Val loss: 0.4117, Val acc: 79.0123%, Best Val loss: 0.4012 Best Val acc: 85.19%
# Epoch 66/200, Train loss: 0.5248, Train acc: 73.0159%, Val loss: 0.4087, Val acc: 83.9506%, Best Val loss: 0.4012 Best Val acc: 85.19%
# Epoch 67/200, Train loss: 0.4806, Train acc: 79.3651%, Val loss: 0.7235, Val acc: 62.9630%, Best Val loss: 0.4012 Best Val acc: 85.19%
# Epoch 68/200, Train loss: 0.5839, Train acc: 73.5450%, Val loss: 0.4726, Val acc: 75.3086%, Best Val loss: 0.4012 Best Val acc: 85.19%
# Epoch 69/200, Train loss: 0.5083, Train acc: 70.3704%, Val loss: 0.6049, Val acc: 61.7284%, Best Val loss: 0.4012 Best Val acc: 85.19%
# Epoch 70/200, Train loss: 0.5620, Train acc: 71.9577%, Val loss: 0.6121, Val acc: 65.4321%, Best Val loss: 0.4012 Best Val acc: 85.19%
# Epoch 71/200, Train loss: 0.4701, Train acc: 74.0741%, Val loss: 0.4609, Val acc: 76.5432%, Best Val loss: 0.4012 Best Val acc: 85.19%
# Epoch 72/200, Train loss: 0.4682, Train acc: 78.3069%, Val loss: 0.4104, Val acc: 82.7160%, Best Val loss: 0.4012 Best Val acc: 85.19%
# Epoch 73/200, Train loss: 0.4242, Train acc: 78.3069%, Val loss: 0.4059, Val acc: 83.9506%, Best Val loss: 0.4012 Best Val acc: 85.19%
# Epoch 74/200, Train loss: 0.3954, Train acc: 80.4233%, Val loss: 0.4037, Val acc: 82.7160%, Best Val loss: 0.4012 Best Val acc: 85.19%
# Epoch 75/200, Train loss: 0.3887, Train acc: 83.0688%, Val loss: 0.4110, Val acc: 81.4815%, Best Val loss: 0.4012 Best Val acc: 85.19%
# Epoch 76/200, Train loss: 0.4050, Train acc: 80.9524%, Val loss: 0.3916, Val acc: 83.9506%, Best Val loss: 0.3916 Best Val acc: 85.19%
# Epoch 77/200, Train loss: 0.4537, Train acc: 77.7778%, Val loss: 0.5076, Val acc: 76.5432%, Best Val loss: 0.3916 Best Val acc: 85.19%
# Epoch 78/200, Train loss: 0.4056, Train acc: 82.5397%, Val loss: 0.3806, Val acc: 85.1852%, Best Val loss: 0.3806 Best Val acc: 85.19%
# Epoch 79/200, Train loss: 0.3824, Train acc: 83.0688%, Val loss: 0.4318, Val acc: 81.4815%, Best Val loss: 0.3806 Best Val acc: 85.19%
# Epoch 80/200, Train loss: 0.3851, Train acc: 82.0106%, Val loss: 0.4314, Val acc: 80.2469%, Best Val loss: 0.3806 Best Val acc: 85.19%
# Epoch 81/200, Train loss: 0.3863, Train acc: 81.4815%, Val loss: 0.3973, Val acc: 83.9506%, Best Val loss: 0.3806 Best Val acc: 85.19%
# Epoch 82/200, Train loss: 0.3793, Train acc: 83.5979%, Val loss: 0.3815, Val acc: 85.1852%, Best Val loss: 0.3806 Best Val acc: 85.19%
# Epoch 83/200, Train loss: 0.3668, Train acc: 83.0688%, Val loss: 0.3862, Val acc: 81.4815%, Best Val loss: 0.3806 Best Val acc: 85.19%
# Epoch 84/200, Train loss: 0.3691, Train acc: 82.0106%, Val loss: 0.3972, Val acc: 81.4815%, Best Val loss: 0.3806 Best Val acc: 85.19%
# Epoch 85/200, Train loss: 0.3846, Train acc: 83.5979%, Val loss: 0.3862, Val acc: 85.1852%, Best Val loss: 0.3806 Best Val acc: 85.19%
# Epoch 86/200, Train loss: 0.3662, Train acc: 83.5979%, Val loss: 0.3747, Val acc: 85.1852%, Best Val loss: 0.3747 Best Val acc: 85.19%
# Epoch 87/200, Train loss: 0.3683, Train acc: 83.5979%, Val loss: 0.3837, Val acc: 82.7160%, Best Val loss: 0.3747 Best Val acc: 85.19%
# Epoch 88/200, Train loss: 0.3951, Train acc: 79.8942%, Val loss: 0.5699, Val acc: 67.9012%, Best Val loss: 0.3747 Best Val acc: 85.19%
# Epoch 89/200, Train loss: 0.4055, Train acc: 80.9524%, Val loss: 0.3834, Val acc: 83.9506%, Best Val loss: 0.3747 Best Val acc: 85.19%
# Epoch 90/200, Train loss: 0.4040, Train acc: 82.5397%, Val loss: 0.4192, Val acc: 81.4815%, Best Val loss: 0.3747 Best Val acc: 85.19%
# Epoch 91/200, Train loss: 0.3871, Train acc: 80.4233%, Val loss: 0.4016, Val acc: 81.4815%, Best Val loss: 0.3747 Best Val acc: 85.19%
# Epoch 92/200, Train loss: 0.3749, Train acc: 82.0106%, Val loss: 0.3930, Val acc: 81.4815%, Best Val loss: 0.3747 Best Val acc: 85.19%
# Epoch 93/200, Train loss: 0.3728, Train acc: 81.4815%, Val loss: 0.4395, Val acc: 79.0123%, Best Val loss: 0.3747 Best Val acc: 85.19%
# Epoch 94/200, Train loss: 0.4358, Train acc: 79.8942%, Val loss: 0.5214, Val acc: 72.8395%, Best Val loss: 0.3747 Best Val acc: 85.19%
# Epoch 95/200, Train loss: 0.5297, Train acc: 74.0741%, Val loss: 0.3806, Val acc: 83.9506%, Best Val loss: 0.3747 Best Val acc: 85.19%
# Epoch 96/200, Train loss: 0.4140, Train acc: 80.9524%, Val loss: 0.4039, Val acc: 81.4815%, Best Val loss: 0.3747 Best Val acc: 85.19%
# Epoch 97/200, Train loss: 0.4225, Train acc: 77.7778%, Val loss: 0.5299, Val acc: 75.3086%, Best Val loss: 0.3747 Best Val acc: 85.19%
# Epoch 98/200, Train loss: 0.4158, Train acc: 79.8942%, Val loss: 0.4072, Val acc: 80.2469%, Best Val loss: 0.3747 Best Val acc: 85.19%
# Epoch 99/200, Train loss: 0.4566, Train acc: 78.8360%, Val loss: 0.3803, Val acc: 83.9506%, Best Val loss: 0.3747 Best Val acc: 85.19%
# Epoch 100/200, Train loss: 0.3898, Train acc: 82.5397%, Val loss: 0.4456, Val acc: 77.7778%, Best Val loss: 0.3747 Best Val acc: 85.19%
# Epoch 101/200, Train loss: 0.3793, Train acc: 81.4815%, Val loss: 0.3937, Val acc: 81.4815%, Best Val loss: 0.3747 Best Val acc: 85.19%
# Epoch 102/200, Train loss: 0.3463, Train acc: 84.6561%, Val loss: 0.3853, Val acc: 81.4815%, Best Val loss: 0.3747 Best Val acc: 85.19%
# Epoch 103/200, Train loss: 0.3727, Train acc: 83.0688%, Val loss: 0.3880, Val acc: 81.4815%, Best Val loss: 0.3747 Best Val acc: 85.19%
# Epoch 104/200, Train loss: 0.3618, Train acc: 82.0106%, Val loss: 0.3747, Val acc: 83.9506%, Best Val loss: 0.3747 Best Val acc: 85.19%
# Epoch 105/200, Train loss: 0.3840, Train acc: 84.6561%, Val loss: 0.4354, Val acc: 80.2469%, Best Val loss: 0.3747 Best Val acc: 85.19%
# Epoch 106/200, Train loss: 0.3464, Train acc: 83.0688%, Val loss: 0.3743, Val acc: 82.7160%, Best Val loss: 0.3743 Best Val acc: 85.19%
# Epoch 107/200, Train loss: 0.3422, Train acc: 86.2434%, Val loss: 0.3925, Val acc: 81.4815%, Best Val loss: 0.3743 Best Val acc: 85.19%
# Epoch 108/200, Train loss: 0.3396, Train acc: 82.5397%, Val loss: 0.3851, Val acc: 81.4815%, Best Val loss: 0.3743 Best Val acc: 85.19%
# Epoch 109/200, Train loss: 0.3618, Train acc: 83.5979%, Val loss: 0.3787, Val acc: 82.7160%, Best Val loss: 0.3743 Best Val acc: 85.19%
# Epoch 110/200, Train loss: 0.3635, Train acc: 83.0688%, Val loss: 0.3800, Val acc: 80.2469%, Best Val loss: 0.3743 Best Val acc: 85.19%
# Epoch 111/200, Train loss: 0.3653, Train acc: 84.1270%, Val loss: 0.3925, Val acc: 81.4815%, Best Val loss: 0.3743 Best Val acc: 85.19%
# Epoch 112/200, Train loss: 0.3813, Train acc: 82.0106%, Val loss: 0.4124, Val acc: 80.2469%, Best Val loss: 0.3743 Best Val acc: 85.19%
# Epoch 113/200, Train loss: 0.3546, Train acc: 83.5979%, Val loss: 0.3941, Val acc: 80.2469%, Best Val loss: 0.3743 Best Val acc: 85.19%
# Epoch 114/200, Train loss: 0.3387, Train acc: 85.1852%, Val loss: 0.3866, Val acc: 81.4815%, Best Val loss: 0.3743 Best Val acc: 85.19%
# Epoch 115/200, Train loss: 0.3568, Train acc: 84.1270%, Val loss: 0.4457, Val acc: 81.4815%, Best Val loss: 0.3743 Best Val acc: 85.19%
# Epoch 116/200, Train loss: 0.3702, Train acc: 83.0688%, Val loss: 0.3684, Val acc: 83.9506%, Best Val loss: 0.3684 Best Val acc: 85.19%
# Epoch 117/200, Train loss: 0.3582, Train acc: 82.5397%, Val loss: 0.3665, Val acc: 83.9506%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 118/200, Train loss: 0.3524, Train acc: 83.0688%, Val loss: 0.3725, Val acc: 83.9506%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 119/200, Train loss: 0.3442, Train acc: 85.1852%, Val loss: 0.3742, Val acc: 85.1852%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 120/200, Train loss: 0.3377, Train acc: 86.2434%, Val loss: 0.3917, Val acc: 79.0123%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 121/200, Train loss: 0.3389, Train acc: 85.7143%, Val loss: 0.3831, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 122/200, Train loss: 0.3419, Train acc: 85.1852%, Val loss: 0.3875, Val acc: 80.2469%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 123/200, Train loss: 0.3337, Train acc: 84.6561%, Val loss: 0.3715, Val acc: 82.7160%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 124/200, Train loss: 0.3501, Train acc: 84.1270%, Val loss: 0.3772, Val acc: 82.7160%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 125/200, Train loss: 0.3436, Train acc: 84.1270%, Val loss: 0.3755, Val acc: 83.9506%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 126/200, Train loss: 0.3250, Train acc: 86.2434%, Val loss: 0.3868, Val acc: 82.7160%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 127/200, Train loss: 0.3376, Train acc: 84.1270%, Val loss: 0.3744, Val acc: 82.7160%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 128/200, Train loss: 0.3754, Train acc: 83.0688%, Val loss: 0.3703, Val acc: 85.1852%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 129/200, Train loss: 0.3579, Train acc: 83.0688%, Val loss: 0.4349, Val acc: 80.2469%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 130/200, Train loss: 0.3757, Train acc: 82.0106%, Val loss: 0.3825, Val acc: 80.2469%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 131/200, Train loss: 0.3416, Train acc: 85.1852%, Val loss: 0.3844, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 132/200, Train loss: 0.3676, Train acc: 82.5397%, Val loss: 0.4286, Val acc: 80.2469%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 133/200, Train loss: 0.3339, Train acc: 81.4815%, Val loss: 0.3891, Val acc: 80.2469%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 134/200, Train loss: 0.3715, Train acc: 84.6561%, Val loss: 0.5016, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 135/200, Train loss: 0.3408, Train acc: 85.1852%, Val loss: 0.4409, Val acc: 79.0123%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 136/200, Train loss: 0.4142, Train acc: 79.8942%, Val loss: 0.4751, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 137/200, Train loss: 0.3327, Train acc: 85.7143%, Val loss: 0.4079, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 138/200, Train loss: 0.3432, Train acc: 85.7143%, Val loss: 0.4228, Val acc: 80.2469%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 139/200, Train loss: 0.3323, Train acc: 86.7725%, Val loss: 0.3725, Val acc: 82.7160%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 140/200, Train loss: 0.3426, Train acc: 84.6561%, Val loss: 0.3835, Val acc: 82.7160%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 141/200, Train loss: 0.3336, Train acc: 85.1852%, Val loss: 0.3694, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 142/200, Train loss: 0.3310, Train acc: 85.7143%, Val loss: 0.3879, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 143/200, Train loss: 0.3315, Train acc: 84.6561%, Val loss: 0.3809, Val acc: 82.7160%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 144/200, Train loss: 0.3389, Train acc: 83.0688%, Val loss: 0.3750, Val acc: 85.1852%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 145/200, Train loss: 0.3277, Train acc: 85.1852%, Val loss: 0.3793, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 146/200, Train loss: 0.3221, Train acc: 84.6561%, Val loss: 0.3741, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 147/200, Train loss: 0.3373, Train acc: 84.1270%, Val loss: 0.3750, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 148/200, Train loss: 0.3321, Train acc: 83.5979%, Val loss: 0.3833, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 149/200, Train loss: 0.3391, Train acc: 85.7143%, Val loss: 0.3706, Val acc: 83.9506%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 150/200, Train loss: 0.3325, Train acc: 84.6561%, Val loss: 0.3839, Val acc: 80.2469%, Best Val loss: 0.3665 Best Val acc: 85.19%
# Epoch 151/200, Train loss: 0.3282, Train acc: 85.1852%, Val loss: 0.3718, Val acc: 86.4198%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 152/200, Train loss: 0.3266, Train acc: 84.6561%, Val loss: 0.3774, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 153/200, Train loss: 0.3220, Train acc: 85.7143%, Val loss: 0.3771, Val acc: 82.7160%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 154/200, Train loss: 0.3324, Train acc: 84.6561%, Val loss: 0.3819, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 155/200, Train loss: 0.3245, Train acc: 85.1852%, Val loss: 0.3724, Val acc: 85.1852%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 156/200, Train loss: 0.3322, Train acc: 83.5979%, Val loss: 0.3816, Val acc: 82.7160%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 157/200, Train loss: 0.3267, Train acc: 86.2434%, Val loss: 0.3730, Val acc: 83.9506%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 158/200, Train loss: 0.3257, Train acc: 85.1852%, Val loss: 0.3914, Val acc: 80.2469%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 159/200, Train loss: 0.3265, Train acc: 86.7725%, Val loss: 0.3737, Val acc: 83.9506%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 160/200, Train loss: 0.3229, Train acc: 85.7143%, Val loss: 0.3832, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 161/200, Train loss: 0.3171, Train acc: 85.1852%, Val loss: 0.3751, Val acc: 85.1852%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 162/200, Train loss: 0.3253, Train acc: 85.7143%, Val loss: 0.3787, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 163/200, Train loss: 0.3254, Train acc: 84.6561%, Val loss: 0.3884, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 164/200, Train loss: 0.3253, Train acc: 84.1270%, Val loss: 0.3742, Val acc: 85.1852%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 165/200, Train loss: 0.3174, Train acc: 85.7143%, Val loss: 0.3833, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 166/200, Train loss: 0.3179, Train acc: 86.2434%, Val loss: 0.3775, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 167/200, Train loss: 0.3236, Train acc: 85.7143%, Val loss: 0.3778, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 168/200, Train loss: 0.3227, Train acc: 85.7143%, Val loss: 0.3869, Val acc: 80.2469%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 169/200, Train loss: 0.3231, Train acc: 86.2434%, Val loss: 0.3732, Val acc: 83.9506%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 170/200, Train loss: 0.3152, Train acc: 86.2434%, Val loss: 0.3751, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 171/200, Train loss: 0.3185, Train acc: 86.2434%, Val loss: 0.3848, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 172/200, Train loss: 0.3157, Train acc: 85.1852%, Val loss: 0.3742, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 173/200, Train loss: 0.3194, Train acc: 86.7725%, Val loss: 0.3728, Val acc: 85.1852%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 174/200, Train loss: 0.3185, Train acc: 87.3016%, Val loss: 0.3825, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 175/200, Train loss: 0.3196, Train acc: 86.2434%, Val loss: 0.3760, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 176/200, Train loss: 0.3176, Train acc: 86.2434%, Val loss: 0.3784, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 177/200, Train loss: 0.3158, Train acc: 86.7725%, Val loss: 0.3750, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 178/200, Train loss: 0.3145, Train acc: 86.7725%, Val loss: 0.3761, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 179/200, Train loss: 0.3148, Train acc: 86.7725%, Val loss: 0.3767, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 180/200, Train loss: 0.3157, Train acc: 86.7725%, Val loss: 0.3770, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 181/200, Train loss: 0.3148, Train acc: 86.7725%, Val loss: 0.3775, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 182/200, Train loss: 0.3150, Train acc: 86.7725%, Val loss: 0.3784, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 183/200, Train loss: 0.3144, Train acc: 85.7143%, Val loss: 0.3810, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 184/200, Train loss: 0.3150, Train acc: 85.7143%, Val loss: 0.3769, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 185/200, Train loss: 0.3149, Train acc: 86.7725%, Val loss: 0.3759, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 186/200, Train loss: 0.3157, Train acc: 86.7725%, Val loss: 0.3768, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 187/200, Train loss: 0.3141, Train acc: 86.7725%, Val loss: 0.3771, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 188/200, Train loss: 0.3157, Train acc: 86.7725%, Val loss: 0.3772, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 189/200, Train loss: 0.3155, Train acc: 86.7725%, Val loss: 0.3761, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 190/200, Train loss: 0.3154, Train acc: 86.7725%, Val loss: 0.3770, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 191/200, Train loss: 0.3122, Train acc: 86.7725%, Val loss: 0.3771, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 192/200, Train loss: 0.3136, Train acc: 86.7725%, Val loss: 0.3774, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 193/200, Train loss: 0.3142, Train acc: 86.7725%, Val loss: 0.3771, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 194/200, Train loss: 0.3120, Train acc: 86.7725%, Val loss: 0.3771, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 195/200, Train loss: 0.3129, Train acc: 86.7725%, Val loss: 0.3770, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 196/200, Train loss: 0.3131, Train acc: 86.7725%, Val loss: 0.3771, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 197/200, Train loss: 0.3128, Train acc: 86.7725%, Val loss: 0.3771, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 198/200, Train loss: 0.3162, Train acc: 86.7725%, Val loss: 0.3771, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 199/200, Train loss: 0.3126, Train acc: 86.7725%, Val loss: 0.3771, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%
# Epoch 200/200, Train loss: 0.3115, Train acc: 86.7725%, Val loss: 0.3771, Val acc: 81.4815%, Best Val loss: 0.3665 Best Val acc: 86.42%

# %% [markdown]
# #### Visualizing the model performance

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

# Plotting training and validation accuracy
ax[0].plot(train_accuracies)
ax[0].plot(val_accuracies)
ax[0].set_title('Model Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(['Train', 'Val'])

# Plotting training and validation loss
ax[1].plot(train_losses)
ax[1].plot(val_losses)
ax[1].set_title('Model Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(['Train', 'Val'])

plt.show()

# %% [markdown]
# ## D. Evaluating Your Trained Model

# %%
# read test file
test_data = pd.read_csv('heart_dataset_test.csv')
test_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   50    0   2       120   219    0        1      158      0      1.6      1
# 1   58    0   2       120   340    0        1      172      0      0.0      2
# 2   66    0   3       150   226    0        1      114      0      2.6      0
# 3   43    1   0       150   247    0        1      171      0      1.5      2
# 4   69    0   3       140   239    0        1      151      0      1.8      2
#
#    ca  thal  target
# 0   0     2       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   2     2       1

# %%
test_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
test_data = test_data.values
test_data.shape
# Out:
# (31, 14)

# %%
# Convert to PyTorch tensors
x_test = torch.from_numpy(test_data[:, :13]).float()
y_test = torch.from_numpy(test_data[:, 13]).long()

# Create datasets
test_dataset = TensorDataset(x_test, y_test)

# Create dataloaders
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
# Load the trained weights
model.load_state_dict(torch.load('model_classification.pth'))

# Set the model to evaluation mode
model.eval()

test_correct = 0
test_total = 0

with torch.no_grad():
    for features, labels in test_loader:

        features = features.cuda()
        labels = labels.cuda()

        outputs = model(features)

        predicted = outputs.argmax(-1)
        test_correct += (predicted == labels).sum().item()
        test_total += labels.size(0)

print(f'Test accuracy is {100. * test_correct / test_total}%')
# Out:
# Test accuracy is 83.87096774193549%
